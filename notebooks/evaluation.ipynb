# %%
# !pip install sdv fairlearn
import pandas as pd
import numpy as np
import os
from pathlib import Path
import pickle

from fairlearn.datasets import fetch_diabetes_hospital
from sklearn.model_selection import train_test_split
from sdv.metadata import Metadata
from sdv.single_table import GaussianCopulaSynthesizer
from sdv.single_table import CTGANSynthesizer
from sdv.single_table import TVAESynthesizer
from sdv.evaluation.single_table import run_diagnostic, evaluate_quality
from sdv.evaluation.single_table import get_column_plot

# %%
data = fetch_diabetes_hospital(as_frame=True)

X = data.data.copy()
y = data.target.copy()

X.shape, y.shape
# Out:
# ((101766, 24), (101766,))

# %%
dropped_columns = ['readmitted', 'readmit_binary']
X = X.drop(columns=dropped_columns)

real_data = X.copy()
real_data['readmit_binary'] = (y == 1)
real_data['readmit_binary'] = real_data['readmit_binary'].astype(bool)
real_data.shape, real_data['readmit_binary'].dtype
# Out:
# ((101766, 23), dtype('bool'))

# %%
real_train, real_test = train_test_split(
    real_data,
    test_size=0.2,
    random_state=66,
    stratify=real_data['readmit_binary']
)

real_train = real_train.reset_index(drop=True)
real_test = real_test.reset_index(drop=True)

real_train.shape, real_test.shape
# Out:
# ((81412, 23), (20354, 23))

# %%
cat_cols = real_train.select_dtypes(include=['category']).columns
real_train[cat_cols] = real_train[cat_cols].astype('object')
real_test[cat_cols] = real_test[cat_cols].astype('object')

real_train['readmit_binary'] = real_train['readmit_binary'].astype(bool)
real_test['readmit_binary'] = real_test['readmit_binary'].astype(bool)

# %%
metadata = Metadata.detect_from_dataframe(
    data=real_train,
    table_name='diabetes'
)

# %%
sensitive_attributes = ['race', 'gender']
for col in sensitive_attributes:
    if col in real_train.columns:
        metadata.update_column(column_name=col, sdtype='categorical')
metadata.update_column(column_name='readmit_binary', sdtype='boolean')
metadata.validate()

# %%
def load_model_syn_data(model_path, sample_len):
    if model_path.exists():
        with model_path.open("rb") as f:
            model = pickle.load(f)
        synthetic_dataset = model.sample(num_rows=sample_len)
        return model, synthetic_dataset

# %%
gc_path = Path("../artifacts/gaussian_copuula_diabetes.pkl")
ct_path = Path("../artifacts/ctgan_diabetes.pkl")
tv_path = Path("../artifacts/tvae_diabetes.pkl")

# %%
sample_len = 81412
gc_model, gc_gendata = load_model_syn_data(gc_path, sample_len)
gc_gendata.head()
# Out:
#         race  gender                    age discharge_disposition_id  \
# 0  Caucasian    Male        'Over 60 years'     'Discharged to Home'
# 1  Caucasian    Male  '30 years or younger'     'Discharged to Home'
# 2  Caucasian    Male          '30-60 years'     'Discharged to Home'
# 3  Caucasian    Male          '30-60 years'     'Discharged to Home'
# 4    Unknown  Female        'Over 60 years'     'Discharged to Home'
#
#   admission_source_id  time_in_hospital       medical_specialty  \
# 0           Emergency                 4                 Missing
# 1           Emergency                 6  Family/GeneralPractice
# 2           Emergency                 4        Emergency/Trauma
# 3           Emergency                 2                 Missing
# 4               Other                 6        InternalMedicine
#
#    num_lab_procedures  num_procedures  num_medications  ... A1Cresult  \
# 0                  54               3                9  ...      None
# 1                  29               0               15  ...      None
# 2                  11               0                5  ...      None
# 3                   6               6                8  ...      None
# 4                  53               0               27  ...      None
#
#    insulin change diabetesMed medicare medicaid had_emergency  \
# 0   Steady     Ch         Yes     True    False         False
# 1       No     Ch         Yes    False    False         False
# 2   Steady     No         Yes     True    False         False
# 3       No     Ch          No    False    False         False
# 4       No     Ch         Yes    False    False         False
#
#   had_inpatient_days had_outpatient_days readmit_binary
# 0               True               False          False
# 1              False                True          False
# 2              False               False          False
# 3               True               False           True
# 4              False                True          False
#
# [5 rows x 23 columns]

# %%
ct_model, ct_gendata = load_model_syn_data(ct_path, sample_len)
ct_gendata.head()
# Out:
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator BayesianGaussianMixture from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#               race  gender              age discharge_disposition_id  \
# 0  AfricanAmerican  Female  'Over 60 years'     'Discharged to Home'
# 1        Caucasian  Female  'Over 60 years'                    Other
# 2         Hispanic    Male    '30-60 years'     'Discharged to Home'
# 3        Caucasian  Female  'Over 60 years'     'Discharged to Home'
# 4        Caucasian  Female    '30-60 years'     'Discharged to Home'
#
#   admission_source_id  time_in_hospital       medical_specialty  \
# 0            Referral                 3                 Missing
# 1           Emergency                 6        InternalMedicine
# 2           Emergency                 4                 Missing
# 3           Emergency                 2                 Missing
# 4            Referral                 4  Family/GeneralPractice
#
#    num_lab_procedures  num_procedures  num_medications  ... A1Cresult  \
# 0                  19               5                6  ...      None
# 1                  62               0               21  ...      None
# 2                  42               2               32  ...      None
# 3                  46               1                9  ...      None
# 4                  40               0               23  ...      None
#
#    insulin change diabetesMed medicare medicaid had_emergency  \
# 0   Steady     No         Yes     True    False         False
# 1       No     No         Yes     True    False         False
# 2       Up     Ch          No    False    False         False
# 3       No     No         Yes     True    False          True
# 4       No     Ch         Yes     True    False         False
#
#   had_inpatient_days had_outpatient_days readmit_binary
# 0              False               False          False
# 1              False               False          False
# 2              False               False          False
# 3              False               False           True
# 4              False               False          False
#
# [5 rows x 23 columns]

# %%
tv_model, tv_gendata = load_model_syn_data(tv_path, sample_len)
tv_gendata.head()
# Out:
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator BayesianGaussianMixture from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#               race  gender              age discharge_disposition_id  \
# 0        Caucasian  Female    '30-60 years'                    Other
# 1        Caucasian  Female  'Over 60 years'                    Other
# 2  AfricanAmerican    Male    '30-60 years'     'Discharged to Home'
# 3        Caucasian  Female    '30-60 years'     'Discharged to Home'
# 4        Caucasian  Female    '30-60 years'                    Other
#
#   admission_source_id  time_in_hospital       medical_specialty  \
# 0           Emergency                 6                   Other
# 1           Emergency                 2                 Missing
# 2           Emergency                 5                 Missing
# 3           Emergency                 8                   Other
# 4           Emergency                 2  Family/GeneralPractice
#
#    num_lab_procedures  num_procedures  num_medications  ... A1Cresult  \
# 0                  50               0               16  ...      None
# 1                   3               0                9  ...      None
# 2                  50               3               10  ...      None
# 3                  41               0               18  ...      None
# 4                  43               0               12  ...      None
#
#    insulin change diabetesMed medicare medicaid had_emergency  \
# 0       No     No          No     True    False         False
# 1       No     No          No    False    False         False
# 2   Steady     No         Yes    False    False         False
# 3   Steady     No         Yes    False    False         False
# 4       No     No          No    False    False         False
#
#   had_inpatient_days had_outpatient_days readmit_binary
# 0              False               False          False
# 1              False               False          False
# 2              False               False          False
# 3              False               False          False
# 4               True               False          False
#
# [5 rows x 23 columns]

# %%
print(type(metadata))
metadata_dict = metadata.to_dict()
print(type(metadata_dict))
# Out:
# <class 'sdv.metadata.metadata.Metadata'>
# <class 'dict'>

# %%
print(metadata_dict.keys())
# Out:
# dict_keys(['tables', 'relationships', 'METADATA_SPEC_VERSION'])

# %%
print(os.getcwd())
# Out:
# /content

# %%
syn_datasets = {
    "GaussianCopula" : gc_gendata,
    "CTGAN" : ct_gendata,
    "TVAE" : tv_gendata,
}

# %%
from sdmetrics.reports.single_table import QualityReport, DiagnosticReport
from sdmetrics.single_column import (
    KSComplement,
    TVComplement,
    CategoryCoverage,
    RangeCoverage,
    MissingValueSimilarity,
    StatisticSimilarity,
    BoundaryAdherence,
    CategoryAdherence,
)
from sdmetrics.column_pairs import CorrelationSimilarity, ContingencySimilarity
from sdmetrics.single_table import NewRowSynthesis, TableStructure
from sdmetrics.visualization import get_column_plot, get_column_pair_plot

# %%
import warnings
from pathlib import Path

# %%
import kaleido

# %%
def save_plot_image(fig, path, width=1200, height=800, scale=2):
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.write_image(str(path), width=width, height=height, scale=scale)

# %%
def save_plot(fig, path):
  try:
    if fig is None:
      return
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.write_html(str(path), include_plotlyjs='cdn')
  except Exception as e:
    warnings.warn(f"Could not save plot to {path} : {e}")

# %%
"""
def quality_reports(real_data : pd.DataFrame, syn_data : pd.DataFrame, \
                metadata_dict, out_dir : Path,):
  out_dir.mkdir(parents=True, exist_ok=True)

  q = QualityReport()
  q.generate(real_data=real_data, synthetic_data=syn_data, \
             metadata=metadata_dict, verbose=False)

  q_score = float(q.get_score())
  q_props = q.get_properties()
  q_col_shapes = q.get_details(property_name="Column Shapes")
  q_col_pairs = q.get_details(property_name="Column Pair Trends")

  q.save(str(out_dir / "quality_report.pkl"))
  q_props.to_csv(out_dir / "quality_properties.csv", index=False)
  q_col_shapes.to_csv(out_dir / "quality_column_shapes.csv", index=False)
  q_col_pairs.to_csv(out_dir / "quality_column_pair_trends.csv", index=False)

  save_plot(q.get_visualization("Column Shapes"), out_dir / "plots" / "quality_column_shapes_scores.html")
  save_plot(q.get_visualization("Column Pair Trends"), out_dir / "plots" / "quality_column_pair_trends_scores.html")
  """
# Out:
#   Cell In[32], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
def quality_reports(real_data : pd.DataFrame, syn_data : pd.DataFrame, metadata_dict, out_dir : Path,):
    out_dir.mkdir(parents=True, exist_ok=True)

    q = QualityReport()
    q.generate(real_data=real_data, synthetic_data=syn_data, \
                metadata=metadata_dict, verbose=False)

    q_score = float(q.get_score())
    q_props = q.get_properties()
    q_col_shapes = q.get_details(property_name="Column Shapes")
    q_col_pairs = q.get_details(property_name="Column Pair Trends")

    q.save(str(out_dir / "quality_report.pkl"))
    q_props.to_csv(out_dir / "quality_properties.csv", index=False)
    q_col_shapes.to_csv(out_dir / "quality_column_shapes.csv", index=False)
    q_col_pairs.to_csv(out_dir / "quality_column_pair_trends.csv", index=False)
    fig_shapes = q.get_visualization("Column Shapes")
    save_plot_image(fig_shapes, out_dir / "plots" / "quality_column_shapes_scores.png")

    fig_pair_trends = q.get_visualization("Column Pair Trends")
    save_plot_image(fig_pair_trends, out_dir / "plots" / "quality_column_pair_trends_scores.png")

# %%
save_dir = Path("../reports")
quality_reports(real_data=real_data, syn_data=syn_datasets["GaussianCopula"], metadata_dict=metadata.to_dict()["tables"]["diabetes"], out_dir=save_dir)
# Out:
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:103: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 save_dir = Path("../reports")
# ----> 2 quality_reports(real_data=real_data, syn_data=syn_datasets["GaussianCopula"], metadata_dict=metadata.to_dict()["tables"]["diabetes"], out_dir=save_dir)
#
# Cell In[33], line 18, in quality_reports(real_data, syn_data, metadata_dict, out_dir)
#      16 q_col_pairs.to_csv(out_dir / "quality_column_pair_trends.csv", index=False)
#      17 fig_shapes = q.get_visualization("Column Shapes")
# ---> 18 save_plot_image(fig_shapes, out_dir / "plots" / "quality_column_shapes_scores.png")
#      20 fig_pair_trends = q.get_visualization("Column Pair Trends")
#      21 save_plot_image(fig_pair_trends, out_dir / "plots" / "quality_column_pair_trends_scores.png")
#
# Cell In[27], line 3, in save_plot_image(fig, path, width, height, scale)
#       1 def save_plot_image(fig, path, width=1200, height=800, scale=2):
#       2     path.parent.mkdir(parents=True, exist_ok=True)
# ----> 3     fig.write_image(str(path), width=width, height=height, scale=scale)
#
# File ~/.conda/envs/capstone_project/lib/python3.11/site-packages/plotly/basedatatypes.py:3895, in BaseFigure.write_image(self, *args, **kwargs)
#    3891     if kwargs.get("engine", None):
#    3892         warnings.warn(
#    3893             ENGINE_PARAM_DEPRECATION_MSG, DeprecationWarning, stacklevel=2
#    3894         )
# -> 3895 return pio.write_image(self, *args, **kwargs)
#
# File ~/.conda/envs/capstone_project/lib/python3.11/site-packages/plotly/io/_kaleido.py:528, in write_image(fig, file, format, scale, width, height, validate, engine)
#     524 format = infer_format(path, format)
#     526 # Request image
#     527 # Do this first so we don't create a file if image conversion fails
# --> 528 img_data = to_image(
#     529     fig,
#     530     format=format,
#     531     scale=scale,
#     532     width=width,
#     533     height=height,
#     534     validate=validate,
#     535     engine=engine,
#     536 )
#     538 # Open file
#     539 if path is None:
#     540     # We previously failed to make sense of `file` as a pathlib object.
#     541     # Attempt to write to `file` as an open file descriptor.
#
# File ~/.conda/envs/capstone_project/lib/python3.11/site-packages/plotly/io/_kaleido.py:345, in to_image(fig, format, width, height, scale, validate, engine)
#     343     # Raise informative error message if Kaleido is not installed
#     344     if not kaleido_available():
# --> 345         raise ValueError(
#     346             """
#     347 Image export using the "kaleido" engine requires the Kaleido package,
#     348 which can be installed using pip:
#     349
#     350     $ pip install --upgrade kaleido
#     351 """
#     352         )
#     354     # Convert figure to dict (and validate if requested)
#     355     fig_dict = validate_coerce_fig_to_dict(fig, validate)
#
# ValueError:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
