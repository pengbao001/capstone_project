# %%
import numpy as np
import pandas as pd
import pickle
import json

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

from fairlearn.metrics import (
    MetricFrame,
    selection_rate,
    demographic_parity_difference,
    demographic_parity_ratio,
    true_positive_rate,
    false_positive_rate,
    count
)

from fairlearn.datasets import fetch_diabetes_hospital

# %%
data = fetch_diabetes_hospital(as_frame=True)
X = data.data.copy()
y = data.target.copy()

dropped_columns = ['readmitted', 'readmit_binary']
X = X.drop(columns=[col for col in dropped_columns if col in X.columns], errors="ignore")

real_data = X.copy()
real_data['readmit_binary'] = (y == 1).astype(int)

real_train, real_test = train_test_split(
    real_data,
    test_size=0.2,
    random_state=66,
    stratify=real_data["readmit_binary"]
)

real_train = real_train.reset_index(drop=True)
real_test = real_test.reset_index(drop=True)

real_train.shape, real_test.shape
# Out:
# ((81412, 23), (20354, 23))

# %%
def build_model_pipeline(X_train : pd.DataFrame, model):
    cat_cols = X_train.select_dtypes(include=["object", "category"]).columns.tolist()
    num_cols = [col for col in X_train.columns if col not in cat_cols]

    numeric_pipe = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler(with_mean=False))
    ])

    categorical_pipe = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ])

    pre = ColumnTransformer(
        transformers = [
            ("num", numeric_pipe, num_cols),
            ("cat", categorical_pipe, cat_cols),
        ],
        remainder="drop"
    )

    pipe = Pipeline(steps=[
        ("preprocess", pre),
        ("model", model)
    ])

    return pipe

# %%
def error_rate(y_true, y_pred):
    return 1.0 - accuracy_score(y_true, y_pred)

def make_fairness_report(y_true, y_pred, sensitive_features, label=""):
    metrics = {
        "count" : count,
        "selection_rate" : selection_rate,
        "accuracy" : accuracy_score,
        "error_rate" : error_rate,
        "TPR" : true_positive_rate,
        "FPR" : false_positive_rate,
    }

    mf = MetricFrame(
        metrics=metrics,
        y_true=y_true,
        y_pred=y_pred,
        sensitive_features=sensitive_features
    )

    dp_diff = demographic_parity_difference(y_true, y_pred, sensitive_features=sensitive_features)
    dp_ratio = demographic_parity_ratio(y_true, y_pred, sensitive_features=sensitive_features)

    by_group = mf.by_group.copy()
    gaps = {}
    for col in ["selection_rate", "error_rate", "TPR", "FPR"]:
        if col in by_group.columns:
            gaps[f"{col}_gap"] = float(by_group[col].max() - by_group[col].min())
    
    summary = {
        "label" : label,
        "dp_diff" : float(dp_diff),
        "dp_ratio" : float(dp_ratio),
        **gaps,
    }

    return {
        "overall" : mf.overall,
        "by_group" : by_group,
        "summary" : summary
    }

# %%
def train_eval_on_real_test(train_df, real_test, target, model, drop_sensitive=False):
    train_df = train_df.copy()
    test_df = real_test.copy()

    sensitive_cols = ["race", "gender"]
    drop_cols = [target]
    if drop_sensitive:
        drop_cols += [col for col in sensitive_cols if col in train_df.columns]

    X_train = train_df.drop(columns=drop_cols, errors="ignore")
    y_train = train_df[target].astype(int)

    X_test = test_df.drop(columns=drop_cols, errors="ignore")
    y_test = test_df[target].astype(int)

    pipe = build_model_pipeline(X_train, model)
    pipe.fit(X_train, y_train)

    y_pred = pipe.predict(X_test)
    return pipe, y_test, y_pred

# %%
def label_rate_by_group(df, target, sensitive):
    y = df[target].astype(int)

    mf = MetricFrame(
        metrics={
            "count" : count,
            "label_rate" : selection_rate,
        },
        y_true=y,
        y_pred=y,
        sensitive_features=sensitive,
    )

    return mf.overall, mf.by_group

# %%
real_overall_r, real_by_r = label_rate_by_group(real_train, "readmit_binary", real_train['race'])
real_overall_g, real_by_g = label_rate_by_group(real_train, "readmit_binary", real_train["gender"])
real_overall_rg, real_by_rg = label_rate_by_group(real_train, "readmit_binary", real_train[["race", "gender"]])

display(real_by_r.sort_values("label_rate", ascending=False).head(10))
display(real_by_g.sort_values("label_rate", ascending=False).head(10))
display(real_by_rg.sort_values("label_rate", ascending=False).head(10))
# Out:
#                    count  label_rate
# race
# Caucasian        60958.0    0.113160
# AfricanAmerican  15257.0    0.112014
# Hispanic          1626.0    0.102706
# Asian              499.0    0.100200
# Other             1208.0    0.092715
# Unknown           1864.0    0.080472
#                    count  label_rate
# gender
# Female           43765.0    0.112441
# Male             37644.0    0.110642
# Unknown/Invalid      3.0    0.000000
#                           count  label_rate
# race            gender
# Caucasian       Female  31791.0    0.114938
# AfricanAmerican Male     5956.0    0.113835
# Asian           Male      246.0    0.113821
# Hispanic        Male      752.0    0.113032
# Caucasian       Male    29167.0    0.111222
# AfricanAmerican Female   9301.0    0.110848
# Other           Female    604.0    0.096026
# Hispanic        Female    874.0    0.093822
# Other           Male      603.0    0.089552
# Asian           Female    253.0    0.086957

# %%
def load_model_syn_data(model_path, sample_len):
    if model_path.exists():
        with model_path.open("rb") as f:
            model = pickle.load(f)
        synthetic_dataset = model.sample(num_rows=sample_len)
        return model, synthetic_dataset

# %%
gc_path = Path("../artifacts/gaussian_copuula_diabetes.pkl")
ct_path = Path("../artifacts/ctgan_diabetes.pkl")
tv_path = Path("../artifacts/tvae_diabetes.pkl")

# %%
sample_len = len(real_train)
gc_model, gc_gendata = load_model_syn_data(gc_path, sample_len)
gc_gendata.head()
# Out:
#         race  gender                    age discharge_disposition_id  \
# 0  Caucasian    Male        'Over 60 years'     'Discharged to Home'
# 1  Caucasian    Male  '30 years or younger'     'Discharged to Home'
# 2  Caucasian    Male          '30-60 years'     'Discharged to Home'
# 3  Caucasian    Male          '30-60 years'     'Discharged to Home'
# 4    Unknown  Female        'Over 60 years'     'Discharged to Home'
#
#   admission_source_id  time_in_hospital       medical_specialty  \
# 0           Emergency                 4                 Missing
# 1           Emergency                 6  Family/GeneralPractice
# 2           Emergency                 4        Emergency/Trauma
# 3           Emergency                 2                 Missing
# 4               Other                 6        InternalMedicine
#
#    num_lab_procedures  num_procedures  num_medications  ... A1Cresult  \
# 0                  54               3                9  ...      None
# 1                  29               0               15  ...      None
# 2                  11               0                5  ...      None
# 3                   6               6                8  ...      None
# 4                  53               0               27  ...      None
#
#    insulin change diabetesMed medicare medicaid had_emergency  \
# 0   Steady     Ch         Yes     True    False         False
# 1       No     Ch         Yes    False    False         False
# 2   Steady     No         Yes     True    False         False
# 3       No     Ch          No    False    False         False
# 4       No     Ch         Yes    False    False         False
#
#   had_inpatient_days had_outpatient_days readmit_binary
# 0               True               False          False
# 1              False                True          False
# 2              False               False          False
# 3               True               False           True
# 4              False                True          False
#
# [5 rows x 23 columns]

# %%
ct_model, ct_gendata = load_model_syn_data(ct_path, sample_len)
ct_gendata.head()
# Out:
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator BayesianGaussianMixture from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#               race  gender              age discharge_disposition_id  \
# 0  AfricanAmerican  Female  'Over 60 years'     'Discharged to Home'
# 1        Caucasian  Female  'Over 60 years'                    Other
# 2         Hispanic    Male    '30-60 years'     'Discharged to Home'
# 3        Caucasian  Female  'Over 60 years'     'Discharged to Home'
# 4        Caucasian  Female    '30-60 years'     'Discharged to Home'
#
#   admission_source_id  time_in_hospital       medical_specialty  \
# 0            Referral                 3                 Missing
# 1           Emergency                 6        InternalMedicine
# 2           Emergency                 4                 Missing
# 3           Emergency                 2                 Missing
# 4            Referral                 4  Family/GeneralPractice
#
#    num_lab_procedures  num_procedures  num_medications  ... A1Cresult  \
# 0                  19               5                6  ...      None
# 1                  62               0               21  ...      None
# 2                  42               2               32  ...      None
# 3                  46               1                9  ...      None
# 4                  40               0               23  ...      None
#
#    insulin change diabetesMed medicare medicaid had_emergency  \
# 0   Steady     No         Yes     True    False         False
# 1       No     No         Yes     True    False         False
# 2       Up     Ch          No    False    False         False
# 3       No     No         Yes     True    False          True
# 4       No     Ch         Yes     True    False         False
#
#   had_inpatient_days had_outpatient_days readmit_binary
# 0              False               False          False
# 1              False               False          False
# 2              False               False          False
# 3              False               False           True
# 4              False               False          False
#
# [5 rows x 23 columns]

# %%
tv_model, tv_gendata = load_model_syn_data(tv_path, sample_len)
tv_gendata.head()
# Out:
# /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator BayesianGaussianMixture from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#               race  gender              age discharge_disposition_id  \
# 0        Caucasian  Female    '30-60 years'                    Other
# 1        Caucasian  Female  'Over 60 years'                    Other
# 2  AfricanAmerican    Male    '30-60 years'     'Discharged to Home'
# 3        Caucasian  Female    '30-60 years'     'Discharged to Home'
# 4        Caucasian  Female    '30-60 years'                    Other
#
#   admission_source_id  time_in_hospital       medical_specialty  \
# 0           Emergency                 6                   Other
# 1           Emergency                 2                 Missing
# 2           Emergency                 5                 Missing
# 3           Emergency                 8                   Other
# 4           Emergency                 2  Family/GeneralPractice
#
#    num_lab_procedures  num_procedures  num_medications  ... A1Cresult  \
# 0                  50               0               16  ...      None
# 1                   3               0                9  ...      None
# 2                  50               3               10  ...      None
# 3                  41               0               18  ...      None
# 4                  43               0               12  ...      None
#
#    insulin change diabetesMed medicare medicaid had_emergency  \
# 0       No     No          No     True    False         False
# 1       No     No          No    False    False         False
# 2   Steady     No         Yes    False    False         False
# 3   Steady     No         Yes    False    False         False
# 4       No     No          No    False    False         False
#
#   had_inpatient_days had_outpatient_days readmit_binary
# 0              False               False          False
# 1              False               False          False
# 2              False               False          False
# 3              False               False          False
# 4               True               False          False
#
# [5 rows x 23 columns]

# %%
syn_datasets = {
    "GaussianCopula" : gc_gendata,
    "CTGAN" : ct_gendata,
    "TVAE" : tv_gendata,
}

# %%
for name, syn_train in syn_datasets.items():
    print("\n=== Synthetic dataset:", name, "===\n")
    o, by = label_rate_by_group(syn_train, "readmit_binary", syn_train[["race","gender"]])
    display(by.sort_values("label_rate", ascending=False).head(10))
# Out:
# === Synthetic dataset: GaussianCopula ===
#                           count  label_rate
# race            gender
# Asian           Male      260.0    0.134615
# Other           Female    588.0    0.117347
# Unknown         Female    921.0    0.116178
# Hispanic        Female    843.0    0.113879
# AfricanAmerican Male     6511.0    0.113807
#                 Female   8421.0    0.113526
# Caucasian       Male    28548.0    0.110165
#                 Female  32749.0    0.109774
# Other           Male      624.0    0.107372
# Asian           Female    216.0    0.101852
# === Synthetic dataset: CTGAN ===
#                                    count  label_rate
# race            gender
# Other           Unknown/Invalid      4.0    0.500000
# Caucasian       Female           51913.0    0.171787
#                 Unknown/Invalid    199.0    0.160804
#                 Male             14895.0    0.152736
# AfricanAmerican Female            5343.0    0.140371
# Unknown         Unknown/Invalid     38.0    0.131579
# Other           Male               493.0    0.117647
# Hispanic        Unknown/Invalid      9.0    0.111111
# Other           Female            2006.0    0.107677
# AfricanAmerican Male              1280.0    0.099219
# === Synthetic dataset: TVAE ===
#                           count  label_rate
# race            gender
# Asian           Male        1.0    1.000000
# Caucasian       Female  43065.0    0.169442
# AfricanAmerican Female  15639.0    0.169384
#                 Male     2583.0    0.166086
# Caucasian       Male    18825.0    0.162497
# Hispanic        Male      110.0    0.154545
#                 Female    447.0    0.149888
# Other           Female    464.0    0.142241
# Asian           Female     15.0    0.133333
# Other           Male      216.0    0.120370

# %%
Target = "readmit_binary"

models = {
    "LogReg": LogisticRegression(max_iter=2000),
    "RandomForest": RandomForestClassifier(
        n_estimators=300,
        random_state=66,
        n_jobs=-1
    ),
}

# %%
all_results = []

A_race   = real_test["race"]
A_gender = real_test["gender"]
A_inter  = real_test[["race","gender"]]

def run_one_setting(setting_name, train_df, model_name, model):
    _, y_true, y_pred = train_eval_on_real_test(
        train_df=train_df,
        real_test=real_test,
        target=Target,
        model=model,
        drop_sensitive=False
    )

    acc = accuracy_score(y_true, y_pred)

    rep_race   = make_fairness_report(y_true, y_pred, A_race,   label=f"{setting_name} | {model_name} | race")
    rep_gender = make_fairness_report(y_true, y_pred, A_gender, label=f"{setting_name} | {model_name} | gender")
    rep_inter  = make_fairness_report(y_true, y_pred, A_inter,  label=f"{setting_name} | {model_name} | race×gender")

    return {
        "setting": setting_name,
        "model": model_name,
        "accuracy": acc,
        "race": rep_race,
        "gender": rep_gender,
        "intersection": rep_inter
    }

for model_name, model in models.items():
    res = run_one_setting("RealTrain->RealTest", real_train, model_name, model)
    all_results.append(res)

for synth_name, syn_train in syn_datasets.items():
    for model_name, model in models.items():
        res = run_one_setting(f"{synth_name}Train->RealTest", syn_train, model_name, model)
        all_results.append(res)

# %%
len(all_results)
# Out:
# 8

# %%
for i, res in enumerate(all_results):
    if res is None:
        print("Row", i, "is None.")
    
    for view_name in ["race", "gender", "intersection"]:
        if res.get(view_name) is None:
            print(
                "Missing view: ", view_name,
                "| index: ", i,
                "| setting: ", res.get("setting"),
                "| model: ", res.get("model"),
            )

# %%
summary_rows = []

for res in all_results:
    for view_name in ["race", "gender", "intersection"]:
        s = res[view_name]["summary"]
        summary_rows.append({
            "setting": res["setting"],
            "model": res["model"],
            "group_view": view_name,
            "accuracy": res["accuracy"],
            "dp_diff": s["dp_diff"],
            "dp_ratio": s["dp_ratio"],
            "selection_rate_gap": s.get("selection_rate_gap", np.nan),
            "error_rate_gap": s.get("error_rate_gap", np.nan),
            "TPR_gap": s.get("TPR_gap", np.nan),
            "FPR_gap": s.get("FPR_gap", np.nan),
        })

summary_df = pd.DataFrame(summary_rows).sort_values(
    ["group_view", "setting", "model"]
)

display(summary_df)
# Out:
#                           setting         model    group_view  accuracy  \
# 13           CTGANTrain->RealTest        LogReg        gender  0.888228
# 16           CTGANTrain->RealTest  RandomForest        gender  0.885428
# 7   GaussianCopulaTrain->RealTest        LogReg        gender  0.888425
# 10  GaussianCopulaTrain->RealTest  RandomForest        gender  0.888277
# 1             RealTrain->RealTest        LogReg        gender  0.888425
# 4             RealTrain->RealTest  RandomForest        gender  0.887442
# 19            TVAETrain->RealTest        LogReg        gender  0.888228
# 22            TVAETrain->RealTest  RandomForest        gender  0.872998
# 14           CTGANTrain->RealTest        LogReg  intersection  0.888228
# 17           CTGANTrain->RealTest  RandomForest  intersection  0.885428
# 8   GaussianCopulaTrain->RealTest        LogReg  intersection  0.888425
# 11  GaussianCopulaTrain->RealTest  RandomForest  intersection  0.888277
# 2             RealTrain->RealTest        LogReg  intersection  0.888425
# 5             RealTrain->RealTest  RandomForest  intersection  0.887442
# 20            TVAETrain->RealTest        LogReg  intersection  0.888228
# 23            TVAETrain->RealTest  RandomForest  intersection  0.872998
# 12           CTGANTrain->RealTest        LogReg          race  0.888228
# 15           CTGANTrain->RealTest  RandomForest          race  0.885428
# 6   GaussianCopulaTrain->RealTest        LogReg          race  0.888425
# 9   GaussianCopulaTrain->RealTest  RandomForest          race  0.888277
# 0             RealTrain->RealTest        LogReg          race  0.888425
# 3             RealTrain->RealTest  RandomForest          race  0.887442
# 18            TVAETrain->RealTest        LogReg          race  0.888228
# 21            TVAETrain->RealTest  RandomForest          race  0.872998
#
#      dp_diff  dp_ratio  selection_rate_gap  error_rate_gap   TPR_gap   FPR_gap
# 13  0.000138  0.697673            0.000138        0.002151  0.000149  0.000173
# 16  0.003923  0.403746            0.003923        0.004197  0.007527  0.003463
# 7   0.000000       NaN            0.000000        0.001983  0.000000  0.000000
# 10  0.000121  0.430001            0.000121        0.001862  0.000000  0.000136
# 1   0.000000       NaN            0.000000        0.001983  0.000000  0.000000
# 4   0.000295  0.859452            0.000295        0.002032  0.001028  0.000197
# 19  0.000667  0.215000            0.000667        0.001953  0.002885  0.000391
# 22  0.005961  0.771112            0.005961        0.005577  0.009997  0.005425
# 14  0.000633  0.000000            0.000633        0.138062  0.001269  0.000572
# 17  0.008990  0.000000            0.008990        0.138062  0.015453  0.008152
# 8   0.000000       NaN            0.000000        0.138062  0.000000  0.000000
# 11  0.000412  0.000000            0.000412        0.138062  0.000000  0.000463
# 2   0.000000       NaN            0.000000        0.138062  0.000000  0.000000
# 5   0.002884  0.000000            0.002884        0.138062  0.005519  0.002780
# 20  0.001966  0.000000            0.001966        0.138062  0.005650  0.001483
# 23  0.030799  0.000000            0.030799        0.138062  0.041943  0.032000
# 12  0.000528  0.000000            0.000528        0.019916  0.001181  0.000446
# 15  0.006142  0.000000            0.006142        0.022869  0.010035  0.005652
# 6   0.000000       NaN            0.000000        0.019916  0.000000  0.000000
# 9   0.000253  0.000000            0.000253        0.020169  0.000000  0.000285
# 0   0.000000       NaN            0.000000        0.019916  0.000000  0.000000
# 3   0.002530  0.000000            0.002530        0.021940  0.005313  0.002566
# 18  0.001265  0.000000            0.001265        0.020675  0.002242  0.001141
# 21  0.027827  0.000000            0.027827        0.033984  0.040359  0.026415

# %%
def show_group_table(setting_contains: str, model_name: str, view="intersection", metric_sort="selection_rate"):
    for res in all_results:
        if (setting_contains in res["setting"]) and (res["model"] == model_name):
            by = res[view]["by_group"].copy()
            display(by.sort_values(metric_sort, ascending=False).head(30))
            return
    print("Not found.")

show_group_table("CTGANTrain->RealTest", "LogReg", view="intersection", metric_sort="error_rate")
# Out:
#                          count  selection_rate  accuracy  error_rate  \
# race            gender
# Asian           Male      77.0        0.000000  0.831169    0.168831
# Hispanic        Male     193.0        0.000000  0.860104    0.139896
# Other           Female   144.0        0.000000  0.868056    0.131944
# AfricanAmerican Male    1526.0        0.000000  0.884010    0.115990
# Caucasian       Female  7898.0        0.000633  0.884908    0.115092
# AfricanAmerican Female  2427.0        0.000000  0.889164    0.110836
# Caucasian       Male    7243.0        0.000414  0.891067    0.108933
# Unknown         Male     218.0        0.000000  0.903670    0.096330
# Other           Male     154.0        0.000000  0.909091    0.090909
# Unknown         Female   191.0        0.000000  0.910995    0.089005
# Hispanic        Female   218.0        0.000000  0.917431    0.082569
# Asian           Female    65.0        0.000000  0.969231    0.030769
#
#                              TPR       FPR
# race            gender
# Asian           Male    0.000000  0.000000
# Hispanic        Male    0.000000  0.000000
# Other           Female  0.000000  0.000000
# AfricanAmerican Male    0.000000  0.000000
# Caucasian       Female  0.001104  0.000572
# AfricanAmerican Female  0.000000  0.000000
# Caucasian       Male    0.001269  0.000310
# Unknown         Male    0.000000  0.000000
# Other           Male    0.000000  0.000000
# Unknown         Female  0.000000  0.000000
# Hispanic        Female  0.000000  0.000000
# Asian           Female  0.000000  0.000000

# %%
out_dir = Path("../artifacts/fairness_report")
out_dir.mkdir(parents=True, exist_ok=True)

summary_df.to_csv(out_dir / "fairness_summary.csv", index=False)

for res in all_results:
    for view_name in ["race", "gender", "intersection"]:
        by = res[view_name]["by_group"].reset_index()
        safe_name = res["setting"].replace("->", "_to_").replace("×", "x").replace(" ", "_")
        by.to_csv(out_dir / f"bygroup__{safe_name}__{res['model']}__{view_name}.csv", index=False)

print("Saved to:", out_dir)
# Out:
# Saved to: ../artifacts/fairness_report

# %%
# Out:
# 2026-03-02 06:13:54.752 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:54.963
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/pengbaoz/.conda/envs/capstone_project/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-03-02 06:13:54.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:54.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:54.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:54.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:54.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.556 Session state does not function when running a script without `streamlit run`
# 2026-03-02 06:13:55.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 06:13:55.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
